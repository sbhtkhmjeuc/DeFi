# %%
from web3 import Web3
# Out:
# ---------------------------------------------------------------------------
# FFIError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=0'>1</a> from web3 import Web3
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\web3\__init__.py:6, in <module>
#       2 import warnings
#       4 import pkg_resources
# ----> 6 from eth_account import (
#       7     Account  # noqa: E402,
#       8 )
#       9 from web3.main import (
#      10     Web3  # noqa: E402,
#      11 )
#      12 from web3.providers.eth_tester import (  # noqa: E402
#      13     EthereumTesterProvider,
#      14 )
#
# ...
